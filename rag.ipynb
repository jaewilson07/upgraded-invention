# %% [markdown]
# ## Get File

# %%
# %pip install domolibrary_extensions

# %%
from math import ceil
import process_files as pf

def chunk_into_n(ls, chunk_size):
  return [ls[i * chunk_size:(i + 1) * chunk_size] for i in range((len(ls) + chunk_size - 1) // chunk_size )] 

file_ls = pf.crawl_directory(file_path = "./content")
chunk_ls = chunk_into_n(file_ls, 5)
chunk_ls
# Out:
# [['./content/s_article_1500000572542/index.html',
#   './content/s_article_360056669354/index.html',
#   './content/s_article_360043427513/index.html',
#   './content/s_article_360043431553/index.html',
#   './content/s_article_1500003263261/index.html'],
#  ['./content/s_article_360042928494/index.html',
#   './content/s_article_360042933854/index.html',
#   './content/s_article_360042923674/index.html',
#   './content/s_article_1500003956542/index.html',
#   './content/s_article_360043436053/index.html'],
#  ['./content/s_article_360044876614/index.html',
#   './content/s_article_360060598333/index.html',
#   './content/s_article_360060507713/index.html',
#   './content/s_article_360042930034/index.html',
#   './content/s_article_9337403057943/index.html'],
#  ['./content/s_article_360042927114/index.html',
#   './content/s_article_360043434613/index.html',
#   './content/s_article_4420450699415/index.html',
#   './content/s_article_360047553253/index.html',
#   './content/s_article_360043430973/index.html'],
#  ['./content/s_article_360045163773/index.html',
#   './content/s_topic_0TO5w000000ZlOmGAK/index.html',
#   './content/s_article_4405156517527/index.html',
#   './content/s_article_4406022964375/index.html',
#   './content/s_article_360042934194/index.html'],
#  ['./content/s_article_1500009366622/index.html',
#   './content/s_article_360057013414/index.html',
#   './content/s_article_360057028494/index.html',
#   './content/s_article_360042929154/index.html',
#   './content/s_topic_0TO5w000000ZanjGAC/index.html'],
#  ['./content/s_article_360042922874/index.html',
#   './content/s_article_360042926134/index.html',
#   './content/s_article_7964629384087/index.html',
#   './content/s_article_360043433753/index.html',
#   './content/s_article_000005342/index.html'],
#  ['./content/s_article_360061648033/index.html',
#   './content/s_topic_0TO5w000000ZanDGAS/index.html',
#   './content/s_article_360042923234/index.html',
#   './content/s_article_360043439893/index.html',
#   './content/s_article_000005174/index.html'],
#  ['./content/s_article_360043435033/index.html',
#   './content/s_article_360043438513/index.html',
#   './content/s_article_360042926694/index.html',
#   './content/s_article_360058892493/index.html',
#   './content/s_article_360043435393/index.html'],
#  ['./content/s_article_1500009258802/index.html',
#   './content/s_article_360042934914/index.html',
#   './content/s_article_360043434233/index.html',
#   './content/s_article_360042931094/index.html',
#   './content/s_article_360042923434/index.html'],
#  ['./content/s_article_360043429693/index.html',
#   './content/s_article_360042924174/index.html',
#   './content/s_article_360042929014/index.html',
#   './content/s_article_360042929254/index.html',
#   './content/s_article_5063710836247/index.html'],
#  ['./content/_s_article_360042924034/index.html',
#   './content/s_topic_0TO5w000000Zan1GAC/index.html',
#   './content/s_article_360044365013/index.html',
#   './content/s_article_360043435673/index.html',
#   './content/s_article_360043428553/index.html'],
#  ['./content/s_article_360043436773/index.html',
#   './content/s_article_360043438733/index.html',
#   './content/s_article_360043435253/index.html',
#   './content/s_article_4402801176471/index.html',
#   './content/s_article_360043432493/index.html'],
#  ['./content/s_article_360043430773/index.html',
#   './content/s_article_360043432773/index.html',
#   './content/s_article_000005302/index.html',
#   './content/s_article_360043430613/index.html',
#   './content/s_article_360043435453/index.html'],
#  ['./content/s_article_360042928954/index.html',
#   './content/s_article_360057014674/index.html',
#   './content/s_topic_0TO5w000000ZaoHGAS/index.html',
#   './content/s_article_360042929954/index.html',
#   './content/s_article_000005374/index.html'],
#  ['./content/s_article_360042927794/index.html',
#   './content/s_article_4405691996439/index.html',
#   './content/s_article_360042931394/index.html',
#   './content/s_article_360042934494/index.html',
#   './content/s_article_360051062653/index.html'],
#  ['./content/s_article_360043428013/index.html',
#   './content/s_article_360043438353/index.html',
#   './content/s_article_360043437453/index.html',
#   './content/s_article_360043433973/index.html',
#   './content/s_article_360042933574/index.html'],
#  ['./content/s_article_360042924514/index.html',
#   './content/s_article_360043430173/index.html',
#   './content/s_article_360043435933/index.html',
#   './content/s_article_360043432453/index.html',
#   './content/s_article_360042929314/index.html'],
#  ['./content/s_article_360043437213/index.html',
#   './content/s_article_360043434633/index.html',
#   './content/s_article_360058755394/index.html',
#   './content/s_article_360043439313/index.html',
#   './content/s_article_360042931234/index.html'],
#  ['./content/s_article_360043431373/index.html',
#   './content/s_article_360044407833/index.html',
#   './content/s_article_360043434893/index.html',
#   './content/s_article_4403173731863/index.html',
#   './content/s_article_000005307/index.html'],
#  ['./content/s_article_360043438973/index.html',
#   './content/s_article_360045485833/index.html',
#   './content/s_article_360043436213/index.html',
#   './content/s_article_360042925314/index.html',
#   './content/s_article_360058760154/index.html'],
#  ['./content/s_article_360042926394/index.html',
#   './content/s_topic_0TO5w000000ZapTGAS/index.html',
#   './content/s_article_1500011202222/index.html',
#   './content/s_article_360046074774/index.html',
#   './content/s_article_1500002456742/index.html'],
#  ['./content/s_article_360043437333/index.html',
#   './content/s_article_360043436173/index.html',
#   './content/s_article_360043434053/index.html',
#   './content/s_topic_0TO5w000000ZmHDGA0/index.html',
#   './content/s_article_360042931314/index.html'],
#  ['./content/s_topic_0TO5w000000ZljGGAS/index.html',
#   './content/s_article_360058570934/index.html',
#   './content/s_article_360043434513/index.html',
#   './content/s_article_360042928914/index.html',
#   './content/s_article_360042928194/index.html'],
#  ['./content/s_article_360043434713/index.html',
#   './content/s_article_360056653514/index.html',
#   './content/s_article_000005298/index.html',
#   './content/s_article_360042931734/index.html',
#   './content/s_article_360042928874/index.html'],
#  ['./content/s_article_360043427873/index.html',
#   './content/s_article_360056826934/index.html',
#   './content/s_article_360042934474/index.html',
#   './content/s_article_360042933494/index.html',
#   './content/s_topic_0TO5w000000ZanxGAC/index.html'],
#  ['./content/s_article_360058760314/index.html',
#   './content/s_article_360058904553/index.html',
#   './content/s_article_1500000339801/index.html',
#   './content/s_article_360043878994/index.html',
#   './content/s_article_360057028474/index.html'],
#  ['./content/s_article_000005254/index.html',
#   './content/s_article_360043434413/index.html',
#   './content/s_article_000005377/index.html',
#   './content/s_article_4482007928983/index.html',
#   './content/s_article_360042928094/index.html'],
#  ['./content/s_article_360042927594/index.html',
#   './content/s_article_360061224493/index.html',
#   './content/_s_article_360042923054/index.html',
#   './content/s_article_4662511363351/index.html',
#   './content/s_topic_0TO5w000000ZlOmGAK_20202023/index.html'],
#  ['./content/s_article_5761015577879/index.html',
#   './content/s_article_360043433493/index.html',
#   './content/s_article_360044364413/index.html',
#   './content/s_topic_0TO5w000000ZammGAC/index.html',
#   './content/s_article_360043433873/index.html'],
#  ['./content/s_article_360043429433/index.html',
#   './content/s_article_360042936194/index.html',
#   './content/s_topic_0TO5w000000ZamoGAC/index.html',
#   './content/s_article_000005183/index.html',
#   './content/s_article_360042926334/index.html'],
#  ['./content/s_article_360042931014/index.html',
#   './content/s_article_000005166/index.html',
#   './content/s_article_360043431513/index.html',
#   './content/s_article_360042930474/index.html',
#   './content/s_article_360043438533/index.html'],
#  ['./content/s_article_360043435013/index.html',
#   './content/s_article_360042929134/index.html',
#   './content/s_article_1500011014942/index.html',
#   './content/s_article_360042923174/index.html',
#   './content/s_article_1500000199961/index.html'],
#  ['./content/s_article_360042925334/index.html',
#   './content/s_article_360042933754/index.html',
#   './content/s_article_360043432233/index.html',
#   './content/s_article_360042932854/index.html',
#   './content/s_article_4405318926231/index.html'],
#  ['./content/s_article_360042924034/index.html',
#   './content/s_article_360042932614/index.html',
#   './content/s_article_360048717414/index.html',
#   './content/s_article_360042931874/index.html',
#   './content/s_topic_0TO5w000000ZdT7GAK/index.html'],
#  ['./content/s_article_360043437153/index.html',
#   './content/s_article_360043439513/index.html',
#   './content/s_topic_0TO5w000000ZmOBGA0/index.html',
#   './content/s_article_360061691114/index.html',
#   './content/s_article_360043429033/index.html'],
#  ['./content/s_article_1500001404182/index.html',
#   './content/s_article_4421871310103/index.html',
#   './content/s_article_4410213098903/index.html',
#   './content/s_article_360042925574/index.html',
#   './content/s_article_360043431293/index.html'],
#  ['./content/s_topic_0TO5w000000ZapVGAS/index.html',
#   './content/s_article_360042923934/index.html',
#   './content/s_article_360042930974/index.html',
#   './content/s_article_360042927994/index.html',
#   './content/s_article_7579340458903/index.html'],
#  ['./content/s_article_360042930714/index.html',
#   './content/s_article_360042925994/index.html',
#   './content/s_article_360043432073/index.html',
#   './content/s_article_360042950514/index.html',
#   './content/s_article_360043434433/index.html'],
#  ['./content/s_article_360042932494/index.html',
#   './content/s_article_360043435793/index.html',
#   './content/s_article_360042924634/index.html',
#   './content/s_article_000005164/index.html',
#   './content/s_article_360043433453/index.html'],
#  ['./content/s_article_360042930494/index.html',
#   './content/s_article_000005378/index.html',
#   './content/s_article_360042923734/index.html',
#   './content/s_article_360042923094/index.html',
#   './content/s_article_360060653773/index.html'],
#  ['./content/s_article_4402058407191/index.html',
#   './content/s_article_360043430593/index.html',
#   './content/s_topic_0TO5w000000ZanVGAS/index.html',
#   './content/s_article_1500000285042/index.html',
#   './content/s_topic_0TO5w000000ZaoCGAS/index.html'],
#  ['./content/s_article_000005351/index.html',
#   './content/s_article_360043435153/index.html',
#   './content/s_topic_0TO5w000000ZamqGAC/index.html',
#   './content/s_article_360042928274/index.html',
#   './content/s_article_360042930834/index.html'],
#  ['./content/s_article_360042928294/index.html',
#   './content/s_article_4929230727319/index.html',
#   './content/s_article_360043432673/index.html',
#   './content/s_article_360052884153/index.html',
#   './content/s_article_360042935034/index.html'],
#  ['./content/s_article_360042929454/index.html',
#   './content/s_article_360042927974/index.html',
#   './content/s_article_360042930994/index.html',
#   './content/s_article_360043431773/index.html',
#   './content/s_article_360043438153/index.html'],
#  ['./content/s_article_360043437513/index.html',
#   './content/s_article_4407975319959/index.html',
#   './content/s_article_000005348/index.html',
#   './content/s_article_000005381/index.html',
#   './content/s_article_360043434733/index.html'],
#  ['./content/s_article_360045179713/index.html',
#   './content/s_article_360042933034/index.html',
#   './content/s_article_360044365593/index.html',
#   './content/s_article_360057014534/index.html',
#   './content/s_article_360042927434/index.html'],
#  ['./content/s_article_360042934254/index.html',
#   './content/s_article_360044951294/index.html',
#   './content/s_article_360043436933/index.html',
#   './content/s_article_4412849158167/index.html',
#   './content/s_article_360043435373/index.html'],
#  ['./content/s_article_1500009781442/index.html',
#   './content/s_article_360043439273/index.html',
#   './content/s_article_360043435813/index.html',
#   './content/s_article_360043439173/index.html',
#   './content/s_article_360043436513/index.html'],
#  ['./content/s_article_360042928934/index.html',
#   './content/s_topic_0TO5w000000ZanWGAS/index.html',
#   './content/s_topic_0TO5w000000ZanSGAS/index.html',
#   './content/s_article_360042930134/index.html',
#   './content/s_article_360043439073/index.html'],
#  ['./content/s_article_360043433093/index.html',
#   './content/s_article_360043433933/index.html',
#   './content/s_article_360042931494/index.html',
#   './content/s_article_360043432213/index.html',
#   './content/s_article_360042929714/index.html'],
#  ['./content/s_article_360043432553/index.html',
#   './content/s_article_000005291/index.html',
#   './content/s_article_360042933314/index.html',
#   './content/s_article_360044363633/index.html',
#   './content/s_article_360042923254/index.html'],
#  ['./content/s_article_360043433073/index.html',
#   './content/s_article_9355841270167/index.html',
#   './content/s_article_360058532353/index.html',
#   './content/s_topic_0TO5w000000Zan5GAC/index.html',
#   './content/s_article_360042927574/index.html'],
#  ['./content/s_article_360042934614/index.html',
#   './content/s_article_360043433153/index.html',
#   './content/s_article_360043433513/index.html',
#   './content/s_article_360043428273/index.html',
#   './content/s_article_360043432093/index.html'],
#  ['./content/s_article_360060508773/index.html',
#   './content/s_article_360043437533/index.html',
#   './content/s_article_360043434333/index.html',
#   './content/s_article_360043430033/index.html',
#   './content/s_article_360052105454/index.html'],
#  ['./content/s_article_360043437993/index.html',
#   './content/s_article_360042931114/index.html',
#   './content/s_article_360061854834/index.html',
#   './content/_s_article_360044876194/index.html',
#   './content/s_article_360043435893/index.html'],
#  ['./content/s_article_360042930234/index.html',
#   './content/s_article_360061873754/index.html',
#   './content/s_article_360043427833/index.html',
#   './content/s_article_360042928854/index.html',
#   './content/s_article_360042933354/index.html'],
#  ['./content/s_article_360042933594/index.html',
#   './content/s_article_360042927754/index.html',
#   './content/s_article_360043435233/index.html',
#   './content/s_topic_0TO5w000000Zjd3GAC/index.html',
#   './content/s_article_360042928714/index.html'],
#  ['./content/s_topic_0TO5w000000ZamzGAC/index.html',
#   './content/s_article_360043434313/index.html',
#   './content/s_article_1500000279922/index.html',
#   './content/s_article_4409812099735/index.html',
#   './content/s_article_000005146/index.html'],
#  ['./content/s_article_360043435713/index.html',
#   './content/s_article_4409199658263/index.html',
#   './content/s_article_360043432933/index.html',
#   './content/s_article_360042936294/index.html',
#   './content/s_article_360043429673/index.html'],
#  ['./content/s_article_360043433993/index.html',
#   './content/s_article_360043432013/index.html',
#   './content/s_article_360043433833/index.html',
#   './content/s_article_360052381713/index.html',
#   './content/s_article_360043434213/index.html'],
#  ['./content/s_article_360043437713/index.html',
#   './content/s_article_360043438233/index.html',
#   './content/s_article_360042927354/index.html',
#   './content/s_article_1500000161782/index.html',
#   './content/s_article_1500003408882/index.html'],
#  ['./content/s_article_360043435533/index.html',
#   './content/s_article_360058904853/index.html',
#   './content/s_article_360042931554/index.html',
#   './content/s_article_360043434173/index.html',
#   './content/s_article_360043434393/index.html'],
#  ['./content/s_article_360042934674/index.html',
#   './content/s_article_360058762534/index.html',
#   './content/s_article_000005128/index.html',
#   './content/s_article_360042928974/index.html',
#   './content/s_article_360043432333/index.html'],
#  ['./content/s_article_360042932674/index.html',
#   './content/s_article_360043434813/index.html',
#   './content/s_article_360043434373/index.html',
#   './content/s_article_360042926054/index.html',
#   './content/s_article_360043428433/index.html'],
#  ['./content/s_article_360043432473/index.html',
#   './content/s_article_360043437633/index.html',
#   './content/s_article_360042927314/index.html',
#   './content/s_article_360043440793/index.html',
#   './content/s_article_4404322668951/index.html'],
#  ['./content/s_article_360042934234/index.html',
#   './content/s_article_360043435513/index.html',
#   './content/s_article_1500000218261/index.html',
#   './content/s_article_360042929874/index.html',
#   './content/s_article_360057013754/index.html'],
#  ['./content/s_article_360043430733/index.html',
#   './content/s_article_360044876874/index.html',
#   './content/s_article_360043430873/index.html',
#   './content/s_article_360042923014/index.html',
#   './content/s_article_360043434153/index.html'],
#  ['./content/s_article_360042926014/index.html',
#   './content/s_article_360042930514/index.html',
#   './content/s_article_360042932014/index.html',
#   './content/s_article_360043438893/index.html',
#   './content/s_article_360043434953/index.html'],
#  ['./content/s_article_360043437233/index.html',
#   './content/s_article_360042929794/index.html',
#   './content/s_article_360042927954/index.html',
#   './content/s_article_360043433333/index.html',
#   './content/s_article_360042929294/index.html'],
#  ['./content/s_article_360043430853/index.html',
#   './content/s_article_360043436893/index.html',
#   './content/s_article_360042929094/index.html',
#   './content/s_article_360042929514/index.html',
#   './content/s_article_360043438273/index.html'],
#  ['./content/s_article_360043428813/index.html',
#   './content/s_article_360048127854/index.html',
#   './content/s_article_4405291644311/index.html',
#   './content/s_article_7938701190807/index.html',
#   './content/s_article_360042929534/index.html'],
#  ['./content/s_article_360043437953/index.html',
#   './content/s_article_360043434933/index.html',
#   './content/s_article_360042927454/index.html',
#   './content/s_article_360042923314/index.html',
#   './content/s_article_360043430633/index.html'],
#  ['./content/s_article_000005248/index.html',
#   './content/s_article_360043433313/index.html',
#   './content/s_article_360043436273/index.html',
#   './content/s_article_360042929994/index.html',
#   './content/s_article_360043434573/index.html'],
#  ['./content/s_article_360062526733/index.html',
#   './content/s_article_360043434073/index.html',
#   './content/s_article_360042931174/index.html',
#   './content/s_article_1500000215322/index.html',
#   './content/s_article_360043434013/index.html'],
#  ['./content/s_article_360058685834/index.html',
#   './content/s_article_360042934114/index.html',
#   './content/s_article_360042929594/index.html',
#   './content/s_article_360042930594/index.html',
#   './content/s_article_4407164711447/index.html'],
#  ['./content/s_article_360042936214/index.html',
#   './content/s_topic_0TO5w000000ZanUGAS/index.html',
#   './content/s_topic_0TO5w000000ZapAGAS/index.html',
#   './content/s_article_360043427953/index.html',
#   './content/s_article_360044876194/index.html'],
#  ['./content/s_article_360042924194/index.html',
#   './content/s_topic_0TO5w000000ZaoBGAS/index.html',
#   './content/s_article_360042933974/index.html',
#   './content/s_article_360042923294/index.html',
#   './content/s_article_000005073/index.html'],
#  ['./content/s_article_360042929394/index.html',
#   './content/s_article_360042930014/index.html',
#   './content/s_article_360042928154/index.html',
#   './content/s_article_360042930914/index.html',
#   './content/s_article_4530782510871/index.html'],
#  ['./content/s_article_360042922934/index.html',
#   './content/s_article_360044296573/index.html',
#   './content/s_article_360043433573/index.html',
#   './content/s_topic_0TO5w000000Zan0GAC/index.html',
#   './content/s_article_360042927634/index.html'],
#  ['./content/s_article_360043437273/index.html',
#   './content/s_article_4529227357975/index.html',
#   './content/s_article_360043435973/index.html',
#   './content/s_article_360043872854/index.html',
#   './content/s_topic_0TO5w000000ZlOnGAK/index.html'],
#  ['./content/s_article_360043427493/index.html',
#   './content/s_article_000005143/index.html',
#   './content/s_article_360043439193/index.html',
#   './content/s_article_1500012178021/index.html',
#   './content/s_article_360042923334/index.html'],
#  ['./content/s_article_4423536836631/index.html',
#   './content/s_article_360047231334/index.html',
#   './content/s_article_360042924934/index.html',
#   './content/s_article_360042927234/index.html',
#   './content/s_article_360043431713/index.html'],
#  ['./content/s_article_1500003993182/index.html',
#   './content/s_article_360042929554/index.html',
#   './content/s_article_360043429273/index.html',
#   './content/s_article_360042931534/index.html',
#   './content/s_topic_0TO5w000000Zan8GAC/index.html'],
#  ['./content/s_article_360043433373/index.html',
#   './content/s_article_360061905054/index.html',
#   './content/s_article_360042931054/index.html',
#   './content/s_article_360043431993/index.html',
#   './content/s_article_360042932794/index.html'],
#  ['./content/s_article_360042931774/index.html',
#   './content/s_topic_0TO5w000000ZaoyGAC/index.html',
#   './content/s_article_360043438013/index.html',
#   './content/s_article_360058685594/index.html',
#   './content/s_article_360043428673/index.html'],
#  ['./content/s_article_360042928654/index.html',
#   './content/s_article_360042933094/index.html',
#   './content/s_article_Current-Release-Notes/index.html',
#   './content/s_article_360043431633/index.html',
#   './content/s_article_360043435353/index.html'],
#  ['./content/s_article_360042923834/index.html',
#   './content/s_article_360043438333/index.html',
#   './content/s_article_360042933134/index.html',
#   './content/s_article_360043438653/index.html',
#   './content/s_article_360043433953/index.html'],
#  ['./content/s_article_360043429913/index.html',
#   './content/s_article_360050912013/index.html',
#   './content/s_article_360063698733/index.html',
#   './content/s_article_1500000662341/index.html',
#   './content/s_article_360042928114/index.html'],
#  ['./content/s_article_360043429073/index.html',
#   './content/s_article_360043429573/index.html',
#   './content/s_article_360043212294/index.html',
#   './content/s_article_360058716453/index.html',
#   './content/s_article_000005337/index.html'],
#  ['./content/s_article_360043431073/index.html',
#   './content/s_article_360043432793/index.html',
#   './content/s_article_360043437433/index.html',
#   './content/s_article_360042934014/index.html',
#   './content/s_article_360042933774/index.html'],
#  ['./content/s_topic_0TO5w000000ZanzGAC/index.html',
#   './content/s_article_360042926714/index.html',
#   './content/s_article_360043433413/index.html',
#   './content/s_topic_0TO5w000000Zan7GAC_archived-feature-release-notes/index.html',
#   './content/s_article_360043434793/index.html'],
#  ['./content/s_topic_0TO5w000000ZaoIGAS/index.html',
#   './content/s_article_1500008921782/index.html',
#   './content/s_article_360042930414/index.html',
#   './content/s_article_360042934754/index.html',
#   './content/s_article_360042932874/index.html'],
#  ['./content/s_article_360042927374/index.html',
#   './content/s_article_360043433473/index.html',
#   './content/s_article_360042922994/index.html',
#   './content/s_article_360042927134/index.html',
#   './content/s_article_360042930774/index.html'],
#  ['./content/s_article_360042929654/index.html',
#   './content/s_article_360042931334/index.html',
#   './content/s_article_360052364393/index.html',
#   './content/s_topic_0TO5w000000ZanLGAS/index.html',
#   './content/s_article_360042926414/index.html'],
#  ['./content/s_article_360047400753/index.html',
#   './content/s_article_9240951363095/index.html',
#   './content/s_article_360042929194/index.html',
#   './content/s_article_000005156/index.html',
#   './content/s_article_000005312/index.html'],
#  ['./content/s_topic_0TO5w000000ZanoGAC/index.html',
#   './content/s_article_360042931154/index.html',
#   './content/s_article_360043430893/index.html',
#   './content/s_article_360043432733/index.html',
#   './content/s_article_360057020774/index.html'],
#  ['./content/s_article_360042928374/index.html',
#   './content/s_article_360042934094/index.html',
#   './content/s_article_360043437013/index.html',
#   './content/s_topic_0TO5w000000ZaoGGAS/index.html',
#   './content/s_topic_0TO5w000000ZaoLGAS/index.html'],
#  ['./content/s_article_5005702805271/index.html',
#   './content/s_article_7963308557463/index.html',
#   './content/s_article_1500000162442/index.html',
#   './content/s_article_360043437193/index.html',
#   './content/s_article_360043430093/index.html'],
#  ['./content/s_article_000005255/index.html',
#   './content/s_article_360042925054/index.html',
#   './content/s_article_360042924734/index.html',
#   './content/s_topic_0TO5w000000ZannGAC/index.html',
#   './content/s_article_360042933454/index.html'],
#  ['./content/s_article_360043431453/index.html',
#   './content/s_article_360042926454/index.html',
#   './content/s_article_1500000280482/index.html',
#   './content/s_article_000005279/index.html',
#   './content/s_article_360042928554/index.html'],
#  ['./content/s_article_360042927934/index.html',
#   './content/s_article_360043428393/index.html',
#   './content/s_article_000005276/index.html',
#   './content/s_article_360042924214/index.html',
#   './content/s_article_360043436573/index.html'],
#  ['./content/s_article_7938129701527/index.html',
#   './content/s_topic_0TO5w000000Zan9GAC/index.html',
#   './content/s_article_1500012226542/index.html',
#   './content/s_article_4577793742615/index.html',
#   './content/s_article_360042929754/index.html'],
#  ['./content/s_article_000005112/index.html',
#   './content/s_article_360043434553/index.html',
#   './content/s_article_360043428293/index.html',
#   './content/s_article_000005281/index.html',
#   './content/s_article_360042934374/index.html'],
#  ['./content/s_article_360043630093/index.html',
#   './content/s_article_8230241776791/index.html',
#   './content/s_article_360042927694/index.html',
#   './content/s_article_360043434033/index.html',
#   './content/s_topic_0TO5w000000ZkAlGAK/index.html'],
#  ['./content/s_article_000005178/index.html',
#   './content/s_article_000005171/index.html',
#   './content/s_article_360043439653/index.html',
#   './content/s_article_1500000216941/index.html',
#   './content/s_article_6568218044055/index.html'],
#  ['./content/s_article_360043430833/index.html',
#   './content/s_article_360043429793/index.html',
#   './content/s_article_360043434673/index.html',
#   './content/s_topic_0TO5w000000ZampGAC/index.html',
#   './content/s_article_360043432293/index.html'],
#  ['./content/s_article_360043427793/index.html',
#   './content/s_article_9645646505111/index.html',
#   './content/s_article_1500000285521/index.html',
#   './content/s_article_360042929574/index.html',
#   './content/s_article_360042932234/index.html'],
#  ['./content/s_article_360043437773/index.html',
#   './content/s_article_000005386/index.html',
#   './content/_s_article_360043430653/index.html',
#   './content/s_article_360042934774/index.html',
#   './content/s_article_360043431213/index.html'],
#  ['./content/s_article_360043432513/index.html',
#   './content/s_article_360043431653/index.html',
#   './content/s_article_9338871306135/index.html',
#   './content/s_article_360043431113/index.html',
#   './content/s_article_7872485267991/index.html'],
#  ['./content/s_article_360042930634/index.html',
#   './content/s_article_4624885410583/index.html',
#   './content/s_article_360043435873/index.html',
#   './content/s_article_360042931254/index.html',
#   './content/s_topic_0TO5w000000ZaojGAC/index.html'],
#  ['./content/s_article_000005242/index.html',
#   './content/s_article_4421037429271/index.html',
#   './content/s_article_360042930074/index.html',
#   './content/s_topic_0TO5w000000ZanbGAC/index.html',
#   './content/s_article_360042925954/index.html'],
#  ['./content/s_article_360043436313/index.html',
#   './content/s_article_4403442101143/index.html',
#   './content/s_article_360043434353/index.html',
#   './content/s_article_360043438773/index.html',
#   './content/s_article_360043437913/index.html'],
#  ['./content/s_article_9485049422103/index.html',
#   './content/s_article_360042929334/index.html',
#   './content/s_article_360043931814/index.html',
#   './content/s_article_360043433593/index.html',
#   './content/s_topic_0TO5w000000ZamwGAC/index.html'],
#  ['./content/s_article_360043438313/index.html',
#   './content/s_article_360060476953/index.html',
#   './content/s_article_4402638182935/index.html',
#   './content/s_article_360051563094/index.html',
#   './content/s_article_360042928754/index.html'],
#  ['./content/s_topic_0TO5w000000ZaoUGAS/index.html',
#   './content/s_article_360043429713/index.html',
#   './content/s_article_360042927034/index.html',
#   './content/s_article_360042926234/index.html',
#   './content/s_article_360042930554/index.html'],
#  ['./content/s_article_4415975374231/index.html',
#   './content/s_article_360042924074/index.html',
#   './content/s_article_000005150/index.html',
#   './content/s_article_4404652354583/index.html',
#   './content/s_article_360055259374/index.html'],
#  ['./content/s_article_4402322966807/index.html',
#   './content/s_article_360043438793/index.html',
#   './content/s_article_360042933954/index.html',
#   './content/s_article_360042934354/index.html',
#   './content/s_article_000005364/index.html'],
#  ['./content/s_article_360043431953/index.html',
#   './content/s_article_360063205353/index.html',
#   './content/s_article_360043438373/index.html',
#   './content/s_article_360043430793/index.html',
#   './content/s_article_360045402873/index.html'],
#  ['./content/s_article_360042928474/index.html',
#   './content/s_article_4409575159191/index.html',
#   './content/s_article_9055998801815/index.html',
#   './content/s_article_1500011338561/index.html',
#   './content/s_article_360043434833/index.html'],
#  ['./content/s_article_360043430933/index.html',
#   './content/s_article_360043432873/index.html',
#   './content/s_article_360043429993/index.html',
#   './content/s_article_360045929334/index.html',
#   './content/s_article_360042933794/index.html'],
#  ['./content/s_article_360042927474/index.html',
#   './content/s_article_360042931894/index.html',
#   './content/s_article_360043429513/index.html',
#   './content/s_article_360043436013/index.html',
#   './content/s_article_360042927674/index.html'],
#  ['./content/s_article_360043438453/index.html',
#   './content/s_article_360042930054/index.html',
#   './content/s_article_360043433733/index.html',
#   './content/s_article_360043432133/index.html',
#   './content/s_article_360043428133/index.html'],
#  ['./content/s_article_6618986293271/index.html',
#   './content/s_knowledge-base/index.html',
#   './content/s_article_360043435653/index.html',
#   './content/s_article_360042926494/index.html',
#   './content/s_article_360042924454/index.html'],
#  ['./content/s_article_4409542407063/index.html',
#   './content/s_article_360042934294/index.html',
#   './content/s_article_000005121/index.html',
#   './content/s_article_360042928814/index.html',
#   './content/s_article_360043432813/index.html'],
#  ['./content/s_article_360043438753/index.html',
#   './content/s_article_360043434093/index.html',
#   './content/s_article_360043435073/index.html',
#   './content/s_article_360042923134/index.html',
#   './content/s_article_360043192634/index.html'],
#  ['./content/s_article_360042935154/index.html',
#   './content/s_topic_0TO5w000000ZaoPGAS/index.html',
#   './content/s_article_360042927534/index.html',
#   './content/s_article_360042926674/index.html',
#   './content/s_article_360043437073/index.html'],
#  ['./content/s_topic_0TO5w000000ZamyGAC/index.html',
#   './content/s_article_360042927714/index.html',
#   './content/s_article_000005275/index.html',
#   './content/s_article_360042931914/index.html',
#   './content/s_article_360042931514/index.html'],
#  ['./content/s_article_360042929974/index.html',
#   './content/s_article_360042923594/index.html',
#   './content/s_article_360043437853/index.html',
#   './content/s_article_360042928254/index.html',
#   './content/s_article_4422714455191/index.html'],
#  ['./content/s_article_360043433173/index.html',
#   './content/s_article_360043433893/index.html',
#   './content/s_article_360043437893/index.html',
#   './content/s_article_4410615812759/index.html',
#   './content/s_article_000005131/index.html'],
#  ['./content/s_article_360042923914/index.html',
#   './content/s_article_360042930574/index.html',
#   './content/s_article_4410240311447/index.html',
#   './content/s_article_360060595673/index.html',
#   './content/s_article_360042928994/index.html'],
#  ['./content/s_article_360042924014/index.html',
#   './content/s_article_360043435213/index.html',
#   './content/s_article_360042927494/index.html',
#   './content/s_topic_0TO5w000000ZanCGAS/index.html',
#   './content/s_topic_0TO5w000000Zao2GAC/index.html'],
#  ['./content/s_article_360043428633/index.html',
#   './content/s_article_360042929354/index.html',
#   './content/s_article_360043884834/index.html',
#   './content/s_article_000005244/index.html',
#   './content/s_article_000005172/index.html'],
#  ['./content/s_article_000005173/index.html',
#   './content/s_article_4407021328919/index.html',
#   './content/s_article_360057020834/index.html',
#   './content/s_article_360046750913/index.html',
#   './content/s_article_000005361/index.html'],
#  ['./content/s_topic_0TO5w000000ZapEGAS/index.html',
#   './content/s_article_4425111066903/index.html',
#   './content/s_article_360042929914/index.html',
#   './content/s_article_000005216/index.html',
#   './content/s_article_360042929274/index.html'],
#  ['./content/s_article_360042928514/index.html',
#   './content/s_article_360056826634/index.html',
#   './content/s_article_360044289573/index.html',
#   './content/s_article_360042929614/index.html',
#   './content/s_article_360043433773/index.html'],
#  ['./content/s_article_360060270674/index.html',
#   './content/s_article_360042931354/index.html',
#   './content/s_article_360043431493/index.html',
#   './content/s_article_360042932754/index.html',
#   './content/s_article_360042929634/index.html'],
#  ['./content/s_article_000005371/index.html',
#   './content/s_article_360042926734/index.html',
#   './content/s_article_4410530935447/index.html',
#   './content/s_topic_0TO5w000000ZaoeGAC/index.html',
#   './content/_s_article_360042923034/index.html'],
#  ['./content/s_article_360046752694/index.html',
#   './content/s_topic_0TO5w000000ZanAGAS/index.html',
#   './content/s_article_360043435593/index.html',
#   './content/s_article_360043434253/index.html',
#   './content/s_article_000005249/index.html'],
#  ['./content/s_article_360043434133/index.html',
#   './content/s_article_360042934214/index.html',
#   './content/s_article_360043431593/index.html',
#   './content/s_article_360043435193/index.html',
#   './content/s_article_360042932074/index.html'],
#  ['./content/s_article_360042927834/index.html',
#   './content/s_article_360043432753/index.html',
#   './content/s_article_360042930654/index.html',
#   './content/s_article_360043428073/index.html',
#   './content/s_article_360043433813/index.html'],
#  ['./content/s_article_360043435093/index.html',
#   './content/s_article_1500000200561/index.html',
#   './content/s_article_360042928354/index.html',
#   './content/s_article_1500004736262/index.html',
#   './content/s_topic_0TO5w000000ZamlGAC/index.html'],
#  ['./content/s_article_360042928014/index.html',
#   './content/s_article_360043436293/index.html',
#   './content/s_article_360055244114/index.html',
#   './content/s_article_360042929854/index.html',
#   './content/s_topic_0TO5w000000Zao9GAC/index.html'],
#  ['./content/s_article_360043433613/index.html',
#   './content/s_article_360043431093/index.html',
#   './content/s_article_360043428853/index.html',
#   './content/s_article_360042930374/index.html',
#   './content/s_article_360043433133/index.html'],
#  ['./content/s_article_360043434473/index.html',
#   './content/s_article_360043433393/index.html',
#   './content/s_article_360043433853/index.html',
#   './content/s_article_360043439913/index.html',
#   './content/s_article_360043430753/index.html'],
#  ['./content/s_article_360042927614/index.html',
#   './content/s_article_360043435953/index.html',
#   './content/s_article_360042930274/index.html',
#   './content/s_article_360043432833/index.html',
#   './content/s_article_360042928674/index.html'],
#  ['./content/s_article_7508267092119/index.html',
#   './content/s_article_360042930194/index.html',
#   './content/s_article_360043431433/index.html',
#   './content/s_article_360043435473/index.html',
#   './content/s_article_4405765083543/index.html'],
#  ['./content/s_article_360042928334/index.html',
#   './content/s_article_360042922794/index.html',
#   './content/s_article_360042929894/index.html',
#   './content/s_article_360043428653/index.html',
#   './content/s_article_360043435913/index.html'],
#  ['./content/s_article_360042923034/index.html',
#   './content/s_article_360043428173/index.html',
#   './content/s_article_360043427773/index.html',
#   './content/s_article_360042927894/index.html',
#   './content/s_article_360051270214/index.html'],
#  ['./content/s_article_360043435853/index.html',
#   './content/s_article_000005360/index.html',
#   './content/s_article_360042922974/index.html',
#   './content/s_article_360058892093/index.html',
#   './content/s_topic_0TO5w000000ZapUGAS/index.html'],
#  ['./content/s_article_360042929734/index.html',
#   './content/s_article_000005256/index.html',
#   './content/s_article_360042930434/index.html',
#   './content/s_article_000005100/index.html',
#   './content/_s_article_360042926114/index.html'],
#  ['./content/s_article_360043435333/index.html',
#   './content/s_article_360042923994/index.html',
#   './content/s_article_360042926974/index.html',
#   './content/s_article_1500009135201/index.html',
#   './content/s_topic_0TO5w000000ZaoQGAS/index.html'],
#  ['./content/s_article_360058529233/index.html',
#   './content/s_article_360043434693/index.html',
#   './content/s_article_360043428613/index.html',
#   './content/s_article_360042926954/index.html',
#   './content/s_topic_0TO5w000000Zap7GAC/index.html'],
#  ['./content/s_article_360042930814/index.html',
#   './content/s_article_360042934074/index.html',
#   './content/s_article_360057013954/index.html',
#   './content/s_article_360043429973/index.html',
#   './content/s_article_4416740193303/index.html'],
#  ['./content/s_article_4415872970647/index.html',
#   './content/s_article_000005162/index.html',
#   './content/s_article_360043430953/index.html',
#   './content/s_article_1500009571721/index.html',
#   './content/s_article_360042928414/index.html'],
#  ['./content/s_article_1500000200221/index.html',
#   './content/s_article_360043428733/index.html',
#   './content/s_article_360042928074/index.html',
#   './content/s_article_360042934574/index.html',
#   './content/s_article_1500000281502/index.html'],
#  ['./content/s_article_360043430913/index.html',
#   './content/s_article_360042929114/index.html',
#   './content/s_article_4411277235351/index.html',
#   './content/s_topic_0TO5w000000ZapBGAS/index.html',
#   './content/s_article_360043430293/index.html'],
#  ['./content/s_article_360043435833/index.html',
#   './content/s_article_000005387/index.html',
#   './content/s_article_360043435113/index.html',
#   './content/s_article_360043429953/index.html',
#   './content/s_article_360043438593/index.html'],
#  ['./content/s_article_360043436033/index.html',
#   './content/s_article_360042934514/index.html',
#   './content/s_article_000005080/index.html',
#   './content/s_topic_0TO5w000000ZdTCGA0/index.html',
#   './content/s_article_4410071437335/index.html'],
#  ['./content/s_article_360042926514/index.html',
#   './content/s_article_360043429253/index.html',
#   './content/s_article_360043431573/index.html',
#   './content/s_article_360043431833/index.html',
#   './content/s_article_000005245/index.html'],
#  ['./content/s_article_360042929234/index.html',
#   './content/s_article_360043437393/index.html',
#   './content/s_article_360042931194/index.html',
#   './content/s_article_360043430193/index.html',
#   './content/s_article_360043430513/index.html'],
#  ['./content/s_topic_0TO5w000000ZmGPGA0/index.html',
#   './content/s_article_360042925394/index.html',
#   './content/s_article_360042928894/index.html',
#   './content/s_article_4406661839895/index.html',
#   './content/s_article_360042926574/index.html'],
#  ['./content/s_article_000005154/index.html',
#   './content/s_article_360042931694/index.html',
#   './content/s_article_360042923054/index.html',
#   './content/s_article_360043427533/index.html',
#   './content/s_article_360043437813/index.html'],
#  ['./content/s_article_360042924554/index.html',
#   './content/s_article_360042930894/index.html',
#   './content/s_article_360043428413/index.html',
#   './content/s_article_360055259234/index.html',
#   './content/s_article_8677917495959/index.html'],
#  ['./content/s_article_360043434873/index.html',
#   './content/s_article_360042926754/index.html',
#   './content/s_article_360043439573/index.html',
#   './content/s_article_360042928574/index.html',
#   './content/s_article_360043429353/index.html'],
#  ['./content/s_article_360042930154/index.html',
#   './content/s_article_360043431853/index.html',
#   './content/s_article_360042928034/index.html',
#   './content/s_article_360042931434/index.html',
#   './content/s_article_360043434593/index.html'],
#  ['./content/s_article_360058529493/index.html',
#   './content/s_article_360042932814/index.html',
#   './content/s_article_360043428593/index.html',
#   './content/s_topic_0TO5w000000ZanMGAS/index.html',
#   './content/s_article_360043430453/index.html'],
#  ['./content/s_article_000005099/index.html',
#   './content/s_topic_0TO5w000000Zl7RGAS/index.html',
#   './content/s_article_360043427633/index.html',
#   './content/s_article_360043432193/index.html',
#   './content/s_article_360042932554/index.html'],
#  ['./content/s_article_360042924474/index.html',
#   './content/s_article_360042926634/index.html',
#   './content/s_article_360042928794/index.html',
#   './content/s_article_360042924834/index.html',
#   './content/s_topic_0TO5w000000ZkAMGA0/index.html'],
#  ['./content/s_article_360045713833/index.html',
#   './content/_s_article_360043436293/index.html',
#   './content/s_article_360042930174/index.html',
#   './content/s_article_1500011371462/index.html',
#   './content/s_article_360058708833/index.html'],
#  ['./content/s_article_000005352/index.html',
#   './content/s_article_360043430213/index.html',
#   './content/s_article_360042929414/index.html',
#   './content/s_article_360042926434/index.html',
#   './content/s_article_360042932294/index.html'],
#  ['./content/s_article_360043433793/index.html',
#   './content/s_article_360043435493/index.html',
#   './content/s_article_360043434753/index.html',
#   './content/s_article_360042932414/index.html',
#   './content/s_article_360043428693/index.html'],
#  ['./content/s_article_360043440753/index.html',
#   './content/s_article_7440921035671/index.html',
#   './content/s_article_360042928834/index.html',
#   './content/s_article_360043436113/index.html',
#   './content/s_article_360043428253/index.html'],
#  ['./content/s_article_360042936274/index.html',
#   './content/s_article_360042926274/index.html',
#   './content/s_article_360043437413/index.html',
#   './content/s_article_360043429853/index.html',
#   './content/s_article_360056318074/index.html'],
#  ['./content/s_article_000005145/index.html',
#   './content/s_article_360042930354/index.html',
#   './content/s_topic_0TO5w000000ZanlGAC/index.html',
#   './content/s_article_4662355030423/index.html',
#   './content/s_article_360042924694/index.html'],
#  ['./content/s_article_360060592813/index.html',
#   './content/s_article_360043435733/index.html',
#   './content/s_article_360042925154/index.html',
#   './content/s_article_360042929054/index.html',
#   './content/s_article_1500002835162/index.html'],
#  ['./content/s_article_360043437053/index.html',
#   './content/s_article_4414026824471/index.html',
#   './content/s_article_360043431753/index.html',
#   './content/s_article_360042929774/index.html',
#   './content/s_article_360042935194/index.html'],
#  ['./content/s_article_360043437673/index.html',
#   './content/s_article_360042928434/index.html',
#   './content/s_article_360042932714/index.html',
#   './content/s_article_360042932734/index.html',
#   './content/s_article_360044351913/index.html'],
#  ['./content/_s_article_360047553253/index.html',
#   './content/s_article_360057028974/index.html',
#   './content/s_article_000005350/index.html',
#   './content/s_article_360042933474/index.html',
#   './content/s_article_360043433253/index.html'],
#  ['./content/s_topic_0TO5w000000ZanwGAC/index.html',
#   './content/s_article_1500000214222/index.html',
#   './content/s_article_360058792094/index.html',
#   './content/s_article_360042922954/index.html',
#   './content/s_article_360042930114/index.html'],
#  ['./content/s_article_360058891393/index.html',
#   './content/s_article_360042934974/index.html',
#   './content/s_article_360042925634/index.html',
#   './content/s_article_1500000406641/index.html',
#   './content/s_topic_0TO5w000000ZaodGAC/index.html'],
#  ['./content/s_article_360042928634/index.html',
#   './content/s_topic_0TO5w000000ZanvGAC/index.html',
#   './content/s_article_360042931614/index.html',
#   './content/s_article_36004740075/index.html',
#   './content/s_article_360042932434/index.html'],
#  ['./content/s_article_360042925774/index.html',
#   './content/s_article_360042929694/index.html',
#   './content/s_article_360043439733/index.html',
#   './content/s_article_360058716313/index.html',
#   './content/s_article_360042929434/index.html'],
#  ['./content/s_article_360043433693/index.html',
#   './content/s_article_360043434913/index.html',
#   './content/s_article_360043431053/index.html',
#   './content/s_article_9301034807575/index.html',
#   './content/s_topic_0TO5w000000ZlmeGAC/index.html'],
#  ['./content/s_article_360043428793/index.html',
#   './content/s_topic_0TO5w000000ZamwGAC_release-notes/index.html',
#   './content/s_article_360042924774/index.html',
#   './content/s_topic_0TO5w000000Zan7GAC/index.html',
#   './content/s_article_360043435313/index.html'],
#  ['./content/s_article_1500000196942/index.html',
#   './content/s_article_360042931454/index.html',
#   './content/s_article_360042926894/index.html',
#   './content/s_topic_0TO5w000000ZamzGAC_transforming-data-in-domo/index.html',
#   './content/s_article_4407033316887/index.html'],
#  ['./content/s_article_360042925814/index.html',
#   './content/s_article_360042929474/index.html',
#   './content/s_article_360043431473/index.html',
#   './content/s_article_360043429293/index.html',
#   './content/s_article_360042925414/index.html'],
#  ['./content/s_topic_0TO5w000000Zan4GAC/index.html',
#   './content/s_article_360042927874/index.html',
#   './content/s_article_360042928694/index.html',
#   './content/s_article_360042931294/index.html']]

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models import ChatOllama

summarize_docs_chain = (
    ChatPromptTemplate.from_template("Summarize the following document for retrieval with LLMs.  Emphasize hyptheticals that could be answered with this content:\n\n{doc}")
    | ChatOllama(
        model="mistral:instruct",
        api_key="not needed",
        # base_url="http://localhost:11434/v1",
        max_retries=0,
        stream= True
    )
    | StrOutputParser()
)

# summarize_docs_chain.invoke("i really like apples, apples consist of pears and oranges")

# %%
from langchain.docstore.document import Document

def load_document(file_path)-> Document:
    """returns content complete with metadata for document"""
    soup = None
    try:
        soup = pf.extract_content_soup(file_path)
        res = pf.extract_article(soup)
        res['metadata'].update({
            "file_path" : file_path,
        })

        res.update({"summary" : summarize_docs_chain.invoke(res['page_content'])})

        return res

    except Exception as e:
        print(e, file_path)
        return False

docs = [load_document(file_path) for file_path in chunk_ls[0]]
docs = [doc for doc in docs if doc]
docs
# Out:
# [{'page_content': 'Intro\n-----\n\n\nRetail Express is a cloud-based POS, inventory, and eCommerce software that provides inventory-based Australian and NZ retailers with a central platform. It helps to manage sales and services, inventory and logistics, marketing, and loyalty, business intelligence practices, and much more across multiple online stores. As a cloud solution, Retail Express gives you the flexibility to manage your business anytime, anywhere, via any internet-enabled devices. Reports and dashboards give users valuable insight into business performance. The Retail Express Web Store API and the IPS API are the web services that allow e-commerce web sites to communicate with Retail Express point of sale and stock control software. This enables the synchronization of products, pricing, purchase orders, customers, internal transfers, and other business-specific information to help reduce the amount of administration required to maintain an online e-commerce website and an IPS. Use Domo\'s Retail Express connector to retrieve the web store and inventory planning systems data.\n\n\nThe Retail Express Connector is a "Cloud App" Connector, meaning it retrieves data stored in the cloud. In the Data Center, you can access the Connector page for this and other Cloud App Connectors by clicking **Cloud App** in the toolbar at the top of the window.\n\n\nYou connect to your Retail Express account in the Data Center. This topic discusses the fields and menus that are specific to the Retail Express\xa0Connector user interface. General information for adding DataSets, setting update schedules, and editing DataSet information is discussed in Adding a DataSet Using a Data Connector.\n\n\n| **Primary Use Cases** | This Connector lets you retrieve data about sales and services, inventory and logistics, marketing, and business intelligence practices. |\n| --- | --- |\n| **Primary Metrics** | * Customer Data * Customer Details * Order Details * Purchase Order Details * Staff Details * Supplier Details * Outlet |\n| **Primary Company Roles** | * Inventory Management * Sales and Services * Logistics * Marketing * Marketing Analytics |\n| **Average Implementation Time** | Less than an hour. |\n| **Ease of Use (on a 1-to-10 scale with 1 being easiest)** | 3 |\n\n\nPrerequisites\n-------------\n\n\nTo connect to your Retail Express account and create a DataSet, you must have the following:\n\n\n* Your domain name of the web service account\n* Your unique client code of retail express account\n* The username and password associated with your Retails Express account\n\n\nConnecting to Your Retails Express\xa0Account\n------------------------------------------\n\n\nThis section enumerates the options in the Credentials and Details panes in the Retails Express Connector page. The components of the other panes in this page, **Scheduling** and **Name & Describe Your DataSet**, are universal across most connector types and are discussed in greater length in Adding a DataSet Using a Data Connector.\n\n\n### Credentials Pane\n\n\nThis pane contains fields for entering credentials to connect to your Retails Express\xa0account. The following table describes what is needed for each field:\n\n Field | Description |\n| --- | --- |\n| Domain | Enter your domain name of the web service account. |\n| Client ID | Enter your unique client code of retail express account. |\n| Username | Enter the username associated with your Retail Express account. |\n| Password | Enter the password associated with your Retail Express account. |\n\n\nOnce you have entered valid Retails Express\xa0credentials, you can use the same account any time you go to create a new Retails Express DataSet. You can manage Connector accounts in the **Accounts** tab in the Data Center. For more information about this tab, see Managing User Accounts for Connectors.\n\n\n### Details Pane\n\n\nThis pane contains a primary **Reports** menu, along with various other menus which may or may not app ...
#   'metadata': {'title': 'Retail Express Connector',
#    'article_number': '000003250',
#    'language': 'English',
#    'article_total_view_count': 6143,
#    'first_published_date': '2022-10-24',
#    'url': 'https://domo-support.domo.com/s/article/1500000572542',
#    'file_path': './content/s_article_1500000572542/index.html'},
#   'summary': ' The Retail Express connector is a cloud-based solution that allows retailers in Australia and New Zealand to manage their sales, inventory, logistics, marketing, and business intelligence across multiple online stores using a central platform. The connector retrieves data from the Retail Express system through its Web Store API and IPS API, which synchronizes products, pricing, purchase orders, customers, internal transfers, and other business information to reduce administrative work for maintaining both an e-commerce website and an inventory management system (IPS).\n\nTo use this connector in Domo, you will need your domain name, unique client code, username, and password associated with your Retail Express account. In the Connector page, enter these credentials under the Credentials pane. Once validated, you can select reports and other parameters from the Details pane, which includes various menus such as Customer Data, Customer Details, Order Details, Product Details, and more. The specific report and date selection can be chosen based on your needs.\n\nThis connector is easy to set up and has a quick implementation time. Some common issues include ensuring valid authentication and checking the configuration settings in the Connector history for error messages. In rare cases, API limitations or timeouts might occur due to requesting too much information; in such instances, you may need to reduce the number of accounts being pulled or choose fewer metrics for a report.\n\nSome frequently asked questions include what credentials are required (domain name, unique client code, username, and password), if there are any API limits (no), and whether you can use the same account to create multiple datasets (yes).'},
#  {'page_content': 'Intro\n-----\n\n\nDomo Workbench is a secure, client-side solution for uploading your on-premise data to Domo.\n\n\nUse Workbench 5.1 to routinely upload data from external DataSets (ODBC, CSV, Microsoft Excel, Jira, QuickBooks, XML, and JSON) to Domo. You can also secure network communication using a proxy server, manage scheduled jobs, add columns based on calculations, transform columns using regular expressions.\n\n\nWhat You Need to Get Started\n----------------------------\n\n\n* Download Domo Workbench from the **Tool Downloads** menu in the **Admin Center**.\n\n\nWhat can Domo Workbench 5.1 do?\n-------------------------------\n\n\n* Securely upload DataSets to Domo using helpful interface components.\n* Upload data manually or on a schedule.\n* Create groups of DataSet jobs that run on the same schedule.\n* Import and export job files.\n* Preview and validate jobs before you run them.\n* Add, create, save, and delete accounts.\n* Add, create, save, delete, open, preview, and cancel jobs.\n* Revert to a previous version of a job you saved.\n* Add/delete transforms to/from jobs, which includes the following:\n\t+ Add new columns.\n\t+ Change date format.\n\t+ Encrypt sensitive data in specific columns.\n\t+ Filter columns in the DataSet.\n\t+ Set the time zone for the DataSet job.\n\t+ Replace column values in the DataSet.\n\t+ Combine the DataSet with another DataSet.\n* Export/import Excel, CSV, QuickBooks, OLAP, ODBC, JSON, and XML file types.\n* View logs.\n* Send logs as a zip file.\n* Run logs from the command line.\n* Add and manage plugins for using Workbench.\n* Set up notifications for DataSet jobs that can email you if DataSets are uploaded successfully or if it experiences an error.\n\n\nCreating a Job for Uploading Data Using Workbench 5.1\n-----------------------------------------------------\n\n\nYou can upload data from external data sources to Domo after specifying connection and data information as a job, which you can save and use again.\nCreating a DataSet job in Workbench 5.1:\n\n\n1. In the **Jobs** pane, click the **+**\xa0icon to create a new job.\n2. Specify the basic settings for the job, such as the DataSet job name, the method of data transport (such as Local File Provider, ODBC Connection Provider, etc.), the data reader (data source) type (such as JIRA, Excel, etc.), the DataSet name and type, and an optional DataSet description.\n\n*Note:** The DataSet name is the only setting you can change after creating the job. If you want to change any other settings, you will need to create a new job.\n3. After providing the details, click **Create**. A newly added job entry will appear in your jobs listing. However, at this stage, the DataSet Job is still not ready for execution.\n\n\n### Configuring and Scheduling your job\n\n\n1. In the **Configure** subtab for the job:\n\t1. Provide the source of the data in the **Source** menu. For example, if the data source was a local file, you would select the file path here.\n\t2. You can choose whether you want newly uploaded data to REPLACE the existing data in the DataSet or be APPENDED (added) to the existing data. You do this in the **Update method** menu.\n\t3. You can specify the error handling method, and the job run duration and conditions in the **Advanced Settings**. This section provides the advanced options for how your job uploads data in Domo.\n2. You can schedule a DataSet job to routinely upload data from external DataSets to Domo. You can select a **Basic Schedule** (update manually, update when file is changed, or update on a schedule.) Or, you can opt for an **Advanced Schedule**\xa0(once a day, specific days of the week/month, etc.) You can also select the **Schedule mode** to be in **Local time** (of your server/Workbench machine) or **UTC time**. You can also see the next five scheduled run times for the job.\n\n*Note:** If you need your DataSet to update faster than every 15 minutes, please reach out to your accoun ...
#   'metadata': {'title': 'Workbench 5.1',
#    'article_number': '000004880',
#    'language': 'English',
#    'article_total_view_count': 18761,
#    'first_published_date': '2022-10-24',
#    'url': 'https://domo-support.domo.com/s/article/360056669354',
#    'file_path': './content/s_article_360056669354/index.html'},
#   'summary': " The FAQ section appears to be complete, but here's a brief summary for quick reference:\n\n#### Frequently Asked Questions (FAQ) about Workbench 5.1\n\n\n#### **Where can I download the plugins from?**\n\nThe plugins are available to install from the Workbench installer. Select the plugins you would like to install by choosing the checkbox next to them on install.\n\n#### **Do I have to use the plugins to connect to my database?**\n\nIt is not mandatory to use the plugins, but they provide benefits such as reading datatypes directly from the source system and eliminating inconsistencies.\n\n#### **What are the benefits of using the database specific plugins?**\n\nBenefits include reading datatypes directly from the database and eliminating inconsistencies.\n\n#### **What DataSets can I take over?**\n\nAny DataSets that were created by a Connector and for which you have Edit permissions or above.\n\n#### **Can I transfer it back to the Connector if I change my mind?**\n\nNo, moving DataSets from Workbench 5.1 back to a Connector is currently not supported.\n\n#### **Will the DataSet automatically start using the schedule from the Connector?**\n\nNo, you will need to set up a new job in Workbench 5.1 and set up the schedule you would like to use.\n\n#### **What if I accidentally bulk delete multiple jobs?**\n\nWorkbench 5.1 has added an extra confirm step so you can ensure you would like to delete DataSets. Once they have been deleted, they cannot be recovered.\n\n#### **Can I edit DataSets from different providers at the same time?**\n\nFor some Bulk Action options, Workbench 5.1 will ask you to choose which provider jobs you would like to update first because the configuration steps are often different between providers.\n\n#### **Will I be able to block all schema changes?**\n\nYes, when this option is selected, absolutely no schema changes will be allowed and Workbench 5.1 will automatically fail the job.\n\n#### **Can I choose to prevent schema changes on some columns and allow them on others?**\n\nYes, the new protect column allows you to choose which columns will have schema protection and which ones will not. This option is not available when **Block all schema changes** is selected.\n\n#### **If I add a new column to my DataSet will that fail the job?**\n\nIt depends; if you choose to **Allow safe schema changes**, Workbench 5.1 will prevent schema changes on existing columns while allowing new columns to be added to the DataSet.\n\n#### **What date grains are available for partitioning?**\n\nPartitioning will be available for all column types.\n\n#### **Can I convert an existing DataSet to a partitioned DataSet?**\n\nPartitioning is only available on new DataSets in this version. Converting to partitioned DataSets will be available in a future release."},
#  {'page_content': "Intro\n-----\n\n*Note:** \xa0If your organization uses single sign-on (SSO), you cannot change your password using the steps described in this article. Instead, contact your internal IT team to change your password. If you have SSO configured, the login screen displays as in this example:\n\n\nThis article describes how to change your Domo password and troubleshoot potential issues in the following topics:\n\n\n* Change password in user settings\n* Change a forgotten or expired password\n* Change your password before it expires\n* Troubleshooting\n\n\nChange Your Password in User Settings\n-------------------------------------\n\n\nIf your organization uses direct sign-on, you can change your password by following these steps:\n\n\n1. In the Domo navigation header, select\xa0your profile picture to expand the user action menu.\n2. Select\xa0\xa0**Settings**.\n The user **Settings** page opens\xa0with the\xa0**General**tab selected by default.\n3. Under **Security**, select\xa0**Change your password**.\n The **Change Password**\xa0fields display.\n4. Enter your current password in the\xa0**Current Password** field.\n5. Enter your new password in the\xa0**New Password**box. Your password\xa0may\xa0need to meet certain criteria, depending on your organization's settings. See Setting Password Requirements\xa0for more information.\n6. Reenter your new password in the\xa0**Retype New Password**\xa0field.\n7. Select **Save**\xa0to keep your new password or **Cancel**\xa0to return to the settings without changing your password.\n\n\nChange a Forgotten or Expired Password\n--------------------------------------\n\n\nIf you forget your password to sign in to Domo, or if it expires, you can change your password from the login page if you know the email address for your account.\n\n\nFor information about changing your password in your profile, see\xa0Specifying Your Personal Profile Information.\n\n\nFollow these steps to change your password from the login page:\n\n\n1. In an internet\xa0browser, enter your organization's domo URL in this format:\xa0https://*mycompany.*domo.com.\n The login page displays.\n2. Select\xa0**Forgot password?**\n A dialog displays.\n3. Enter your email address, then select\xa0**Request Reset Link**.\n An email is sent to the email address.\n4. Log in to your email account and find the email message.\xa0The email message has the subject line **Forgotten Password**.\xa0If the email doesn't arrive, contact your Domo admin.\n5. Open the email message, then select **Reset Your Password**.\n A dialog appears where you can change your password.\n6. Enter a new password in the first field.\n7. Reenter the same password in the second field.\n8. Select **Reset Your Password**. Your password may need to meet certain requirements. See Setting Password Requirements to learn more.\n\n\n**Note:**\xa0If for any reason you have issues while resetting your password, reach out to an Admin-level user or a user with a custom role for which the Edit Users grant has been enabled. These users have the ability to change a password for a particular user in the Admin Settings in Domo.\n\nhange Your Password Before It Expires\n--------------------------------------\n\n\nWhen password expiration is enabled, your password is set to expire after a specified amount of time. You can change your password in Domo before it expires.\n\n\nA few days before your password expires, a prompt displays after you sign in.\n\n\nFollow these steps to change your password before it expires:\n\n\n1. When prompted, select\xa0**Change your password**.\n2. Enter your current password that is expiring, then enter and confirm a new password.\xa0Your password may need to meet certain requirements. See Setting Password Requirements to learn more.\n3. Select\xa0**Save** to save your new password.\n\n\nTroubleshooting\n---------------\n\n\nIf you try to reset your password and don't receive a password reset email, try the following:\n\n\n* Look  ...
#   'metadata': {'title': 'Change Your Password',
#    'article_number': '000004372',
#    'language': 'English',
#    'article_total_view_count': 13708,
#    'first_published_date': '2022-10-24',
#    'url': 'https://domo-support.domo.com/s/article/360043427513',
#    'file_path': './content/s_article_360043427513/index.html'},
#   'summary': ' This document provides instructions on how to change your Domo password and troubleshoot potential issues in various scenarios: direct sign-on with user settings, forgotten or expired passwords, and changing your password before it expires.\n\n* For direct sign-on users, follow the steps in the "Change Your Password in User Settings" section to modify your current password by visiting your profile settings and filling out the new password fields.\n* If you\'ve forgotten your password or if it has expired, use the instructions in the "Change a Forgotten or Expired Password" section to reset it via email. Enter your email address on the login page\'s "Forgot password?" feature and follow the prompts to receive an email with a link to reset your password.\n* Users can also change their password before it expires by following the instructions in the "Change Your Password Before It Expires" section. When prompted, select "Change your password," enter your current and new passwords, and save the changes.\n* The document offers troubleshooting tips for issues related to password resets, such as checking junk folders for emails, verifying authentication methods (single sign-on or direct sign-on), and double-checking Domo instance URLs. If you still experience difficulties, contact an Admin-level user or a custom role user with the "Edit Users" grant for assistance in changing your password within the Admin Settings of Domo.'},
#  {'page_content': 'Intro\n-----\n\n\nMarketo is a marketing automation SaaS company which develops automated marketing and demand generation software and services for business-to-business marketers. The Domo Marketo connector allows users to pull email and lead level campaign performance information. This enables the reporting and optimization of metrics suchs as lead database growth (MQLs), click-through-rates, delivery rates, sends, opens, and deliveries.\xa0To learn more about\xa0Marketo REST API, visit their\xa0website (http://developers.marketo.com/rest-api/).\n\n\nThe Marketo connector is a "Cloud App" connector, meaning it retrieves data stored in the cloud. In the Data Center, you can access the connector page for this and other Cloud App connectors by clicking **Cloud App** in the toolbar at the top of the window.\n\n\nYou connect to your\xa0Marketo account in the\xa0Data Center. This topic discusses the fields and menus that are specific to the\xa0Marketo connector user interface. General information for adding DataSets, setting update schedules, and editing\xa0DataSet information is discussed in\xa0Adding a DataSet Using a Data Connector.\n\n\n| **Primary Use Cases** | Digital marketing campaign performance reporting and optimization. |\n| --- | --- |\n| **Primary Metrics** | * Emails Sent * Emails Delivered * Emails Opened * Emails Clicked * Click Through Rate * Click to Open Rate * Delivery Rate * Open Rate * Content Clicks * Content Click Through Rate * Marketing Qualified Leads * Lead Velocity |\n| **Primary Company Roles** | * Marketing Director * Marketing Operations * VP of Marketing * Marketing Analyst * Digital Marketing Specialist * Marketing Automation * Outbound Marketing |\n| **Average Implementation Time** | ~50 hours |\n| **Ease of Use (on a 1-to-10 scale with 1 being easiest)** | 7 |\n\n\nPrerequisites\n-------------\n\n\nTo connect to your\xa0Marketo account and create a DataSet, you must have the following:\n\n\n* The Marketo Client ID and Client Secret generated during the creation of your custom service. You can find these by signing into Marketo, navigating to\xa0**Admin > LaunchPoint**, and clicking\xa0**View Details**\xa0for the custom service (which will most likely be named "Domo").\n* The\xa0"Endpoint" and "Identity" URLs. To obtain the Endpoint and Identity URLs, navigate to **Admin > Integration > Web Services** in Marketo.\n\n\nFor step-by-step instructions about creating a Marketo custom service, see\xa0http://developers.marketo.com/documentation/rest/custom-service/.\n\n\nConnecting to Your\xa0Marketo Account\n----------------------------------\n\n\nThis section enumerates the options in the\xa0**Credentials**\xa0and\xa0**Details**\xa0panes in the\xa0Marketo Connector page.\xa0The components of the other panes in this page,\xa0**Scheduling**\xa0and\xa0**Name & Describe Your DataSet**, are universal across most connector types and are discussed in greater length in\xa0Adding a DataSet Using a Data Connector.\n\n\n### Credentials Pane\n\n\nThis pane contains fields for entering credentials to connect to your Marketo account. The following table describes what is needed for each field:\n\n\n| Field | Description |\n| --- | --- |\n| Client ID | Enter the Marketo Client ID generated during the creation of your custom service. |\n| Shared Secret | Enter the Client Secret generated during the creation of your custom service. |\n| Endpoint URL | Enter the "rest" endpoint URL provided when you created a custom service. For example:\xa0https://100-AEK-913.mktorest/com/rest |\n| Identity URL | Enter the "identity"\xa0URL\xa0provided when you created a custom service. For example:\xa0 https://100-AEK-913.mktorest.com/identity |\n\n\nOnce you have entered valid Marketo credentials, you can use the same account any time you go to create a new\xa0Marketo DataSet. You can manage connector accounts in the\xa0Accounts\xa0tab in the\xa0Data Center. For more information about this tab, see\xa0Managing Use ...
#   'metadata': {'title': 'Marketo Connector',
#    'article_number': '000003740',
#    'language': 'English',
#    'article_total_view_count': 12571,
#    'first_published_date': '2022-10-24',
#    'url': 'https://domo-support.domo.com/s/article/360043431553',
#    'file_path': './content/s_article_360043431553/index.html'},
#   'summary': " The document describes the use of the Marketo connector in Domo for retrieving email and lead campaign performance information from Marketo's marketing automation software. The connector allows reporting and optimization of metrics such as MQLs, click-through-rates, delivery rates, opens, and deliveries. Prerequisites include the Marketo Client ID, Client Secret, Endpoint URL, and Identity URL, which are obtained during the creation of a custom service in Marketo. The document provides instructions for entering these credentials in the Credentials pane of the connector interface and selecting a report type in the Details pane. Available reports include All Campaigns, All Lists, All Programs, Daily API Usage, Leads by List, Leads by Program, Leads by Date Modified, and Leads Activities. The document also provides best practices for consulting/support, including utilizing historical reports to backload bulk data and being aware of the customer's API limits. Marketo API limits can be found on their website."},
#  {'page_content': 'Intro\n-----\n\n\nDomo’s improved accessibility functionality allows customers to make their cards screen reader-friendly, as well as find dashboards, traverse layouts, and read card details.\xa0Expanded access for screen readers and keyboards better enables customers with a diverse base of users to expose Domo content to users with accessibility requirements.',
#   'metadata': {'title': 'Support for Screen Readers on Dashboards',
#    'article_number': '000004330',
#    'language': 'English',
#    'article_total_view_count': 12302,
#    'first_published_date': '2022-10-24',
#    'url': 'https://domo-support.domo.com/s/article/1500003263261',
#    'file_path': './content/s_article_1500003263261/index.html'},
#   'summary': " Domo's enhanced accessibility features enable customers to make their cards more accessible to screen reader users. This functionality allows users to find dashboards, navigate layouts, and read card details using screen readers and keyboards. By expanding access for users with accessibility requirements, Domo aims to broaden the reach of its content to a more diverse customer base.\n\nHypothetical questions that could be answered with this content:\n\n1. What new features does Domo offer to make its cards screen reader-friendly?\n2. How do customers use keyboards and screen readers to navigate Domo's dashboards and layouts?\n3. Who are the intended users of Domo's improved accessibility functionality?\n4. Why is it important for businesses to provide accessible content for users with disabilities?"}]

# %% [raw]
# -- wsl
# systemctl stop ollama
# ollama serve
# ollama run llama3:8b

# %%
from langchain_community.embeddings import OllamaEmbeddings

persist_directory = './chroma_db'
embedding_function = OllamaEmbeddings(model="nomic-embed-text")

# %%
from typing import List
from langchain_chroma import Chroma
from langchain.storage import InMemoryByteStore
from langchain.retrievers.multi_vector import MultiVectorRetriever

vectorstore_summary = Chroma(   
    collection_name="summaries",
    persist_directory=persist_directory,
    embedding_function=embedding_function,
)

retriever = MultiVectorRetriever(
    vectorstore=vectorstore_summary,
    docstore=InMemoryByteStore(),
    id_key="article_number",
)

def summarize_chunk(cdocs : List[Document]):
    summary_docs = [
        Document(page_content=doc["summary"], metadata=doc["metadata"]) for doc in cdocs
    ]

    retriever.vectorstore.add_documents(summary_docs, ids  = [doc.metadata['article_number'] for doc in summary_docs])
    retriever.docstore.mset(
        list(
            zip(
                [doc["metadata"]["article_number"] for doc in docs],
                [Document(**doc) for doc in docs],
            )
        )
    )

# %%
for x in range(len(vectorstore_summary.get()["ids"])):
    print(vectorstore_summary.get()["metadatas"][x])
    # doc = vectorstore_summary.get()["metadatas"][x]
    # source = doc["source"]
# Out:
# {'article_number': '000003250', 'article_total_view_count': 6143, 'file_path': './content/s_article_1500000572542/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Retail Express Connector', 'url': 'https://domo-support.domo.com/s/article/1500000572542'}
# {'article_number': '000003740', 'article_total_view_count': 12571, 'file_path': './content/s_article_360043431553/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Marketo Connector', 'url': 'https://domo-support.domo.com/s/article/360043431553'}
# {'article_number': '000004330', 'article_total_view_count': 12302, 'file_path': './content/s_article_1500003263261/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Support for Screen Readers on Dashboards', 'url': 'https://domo-support.domo.com/s/article/1500003263261'}
# {'article_number': '000004372', 'article_total_view_count': 13708, 'file_path': './content/s_article_360043427513/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Change Your Password', 'url': 'https://domo-support.domo.com/s/article/360043427513'}
# {'article_number': '000004880', 'article_total_view_count': 18761, 'file_path': './content/s_article_360056669354/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Workbench 5.1', 'url': 'https://domo-support.domo.com/s/article/360056669354'}

# %%
print('done')
# Out:
# done

# %%
sub_docs = vectorstore_summary.similarity_search('how do i reset my password')
sub_docs
# Out:
# [Document(page_content=" This article provides instructions on how to change your Domo password and troubleshoot potential issues in different scenarios: direct sign-on with user settings, forgotten or expired passwords, and changing a password before it expires.\n\n1. Change password in user settings:\n   - Access the user Settings page by selecting your profile picture and choosing Settings.\n   - Under Security, select Change your password.\n   - Enter current and new passwords, then save or cancel the changes.\n\n2. Change a forgotten or expired password:\n   - If you forget or if it expires, enter your organization's domo URL and select Forgot password? to initiate the password reset process.\n   - Enter your email address and request a reset link.\n   - Open the email message, change your password, and save the changes.\n\n3. Change your password before it expires:\n   - If password expiration is enabled, you'll receive a prompt to change your password before it expires.\n   - Enter your current and new passwords, then save the changes.\n\nTroubleshooting issues:\n- Check your email junk folder for the password reset email.\n- Verify your organization's authentication method (SSO) and contact internal IT to change the password if required.\n- Ensure you enter the correct Domo instance URL (customername.domo.com).\n\nIf you still face issues, reach out to an Admin-level user or a user with custom role having Edit Users grant for assistance in changing your password within Domo. After regaining access, remember to change it again using the user settings to ensure security.", metadata={'article_number': '000004372', 'article_total_view_count': 13708, 'file_path': './content/s_article_360043427513/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Change Your Password', 'url': 'https://domo-support.domo.com/s/article/360043427513'}),
#  Document(page_content=" #### Can I use my Workbench encryption key for data at rest in Domo?\n\nNo, the encryption keys used by Workbench for data at rest are different than the Domo data at rest keys. You'll need to manage your own encryption and decryption process for any data being transferred between your source system and Domo.\n\n#### Is it possible to move a DataSet from one Connector account to another?\n\nNo, moving DataSets between Connector accounts is not supported in Workbench 5.1. You would need to manually delete the DataSet from the old account and create it again in the new account.\n\n#### Can I use both the classic and database plugins at the same time?\n\nYes, you can use both the classic and database plugins simultaneously for different jobs. The choice of which plugin to use depends on the type of connection you need to make. For example, MySQL 5.6 or older will require the classic plugin, while MySQL 8.0 or newer can use the database plugin.\n\n#### What happens if I delete a DataSet in Domo while it's still being used in Workbench?\n\nIf you delete a DataSet from Domo that is still being referenced by a job in Workbench, the job will fail since Workbench cannot find the referenced DataSet. You would need to re-create the deleted DataSet in Domo before you can run your Workbench jobs again.\n\n#### Will the new log capabilities replace existing logs?\n\nNo, enhanced logging is an additional feature that runs alongside the existing logging options. The choice of which logging method to use will depend on your needs.\n\n#### Is there a limit to how many DataSets I can move from my source system using Workbench 5.1?\n\nThere is no specific limit to the number of DataSets you can move, but larger projects or multiple simultaneous jobs may impact performance. We recommend testing in a small environment before working on larger projects or attempting multiple jobs at once.", metadata={'article_number': '000004880', 'article_total_view_count': 18761, 'file_path': './content/s_article_360056669354/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Workbench 5.1', 'url': 'https://domo-support.domo.com/s/article/360056669354'}),
#  Document(page_content=' The Retail Express connector is a cloud-based solution that allows Australian and NZ retailers to manage their sales, inventory, marketing, and business intelligence practices across multiple online stores using a central platform. To connect to this account and create a dataset in Domo, users need their domain name, client code, username, and password. The Retail Express connector page includes a Credentials pane for entering these details and a Details pane with various menus for selecting reports and setting date formats. Reports include Customer Data, Customer Details, Order Details, Product Details, Purchase Orders Details, Staff Details, Supplier Details, and Outlets. Users can select the date format, whether the report data is for a specific or relative date, and specify warehouses to retrieve data for. The connector supports the retrieval of data for all warehouses or a comma-separated list of warehouse IDs. Users can also indicate whether they want to return only customers with emails or only customers marked as export to web. The connector is easy to use and implementation time is less than an hour. Prerequisites include having the domain name, client code, username, and password for your Retail Express account. The connector lets users retrieve data about sales and services, inventory and logistics, marketing, and business intelligence practices with primary metrics including customer data, order details, staff details, supplier details, and outlet information. Primary company roles include inventory management, sales and services, logistics, marketing, and marketing analytics. Users can manage connector accounts in the Accounts tab in the Data Center. The connector supports retrieving data for all warehouses or a specific list of warehouse IDs, and users can choose whether to return only customers with emails or all customers. There are no API limits for this connector and users can use the same account to create multiple datasets. Troubleshooting includes ensuring that authentication remains valid, reviewing the configuration to make sure that all required items have been selected, reviewing the Connector history for error messages, and reducing the amount of data being requested if reaching API limitations or timeouts.', metadata={'article_number': '000003250', 'article_total_view_count': 6143, 'file_path': './content/s_article_1500000572542/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Retail Express Connector', 'url': 'https://domo-support.domo.com/s/article/1500000572542'}),
#  Document(page_content=" Marketo is a marketing automation software company that provides automated marketing and demand generation tools for B2B marketers. The Domo Marketo connector enables users to pull email and lead campaign performance data, including metrics such as MQLs, click-through-rates, delivery rates, opens, and deliveries. The connector is a Cloud App connector, which retrieves data stored in the cloud. To access the connector page, go to the Data Center's Cloud App section.\n\nPrerequisites for connecting to Marketo include a Marketo Client ID and Client Secret, Endpoint URL, and Identity URL. These can be obtained by creating a custom service in Marketo and navigating to its API documentation. The connector allows users to select various reports and menus to retrieve desired data, with options including All Campaigns, Leads by Date Modified, and Lead Activities.\n\nAPI limits for Marketo can be found on their website. Best practices include utilizing historical reports to minimize impact on API limits, verifying the API limit with customers before creating connections, and being cautious of customer API limits to prevent overruns that could cause forms to fail. The connector is generally stable but may encounter discrepancies due to accounting differences with Marketo. In such cases, it's recommended to reach out to Marketo for clarification on their calculations and business logic contained in the front-end reports.", metadata={'article_number': '000003740', 'article_total_view_count': 12571, 'file_path': './content/s_article_360043431553/index.html', 'first_published_date': '2022-10-24', 'language': 'English', 'title': 'Marketo Connector', 'url': 'https://domo-support.domo.com/s/article/360043431553'})]

# %%
# pip install langchain_chroma --upgrade

# %% [markdown]
# # Test

# %%
query = "can i reset my password if my organization uses SSO?"
sub_docs = retriever.get_relevant_documents(query,k=1)

from pprint import pprint
pprint(
    sub_docs[0].__dict__
)
# Out:
# {'metadata': {'article_number': '000004372',
#               'article_total_view_count': 13708,
#               'file_path': './content/s_article_360043427513/index.html',
#               'first_published_date': '2022-10-24',
#               'language': 'English',
#               'title': 'Change Your Password',
#               'url': 'https://domo-support.domo.com/s/article/360043427513'},
#  'page_content': 'Intro\n'
#                  '-----\n'
#                  '\n'
#                  '*Note:** \xa0If your organization uses single sign-on (SSO), '
#                  'you cannot change your password using the steps described in '
#                  'this article. Instead, contact your internal IT team to '
#                  'change your password. If you have SSO configured, the login '
#                  'screen displays as in this example:\n'
#                  '\n'
#                  '\n'
#                  'This article describes how to change your Domo password and '
#                  'troubleshoot potential issues in the following topics:\n'
#                  '\n'
#                  '\n'
#                  '* Change password in user settings\n'
#                  '* Change a forgotten or expired password\n'
#                  '* Change your password before it expires\n'
#                  '* Troubleshooting\n'
#                  '\n'
#                  '\n'
#                  'Change Your Password in User Settings\n'
#                  '-------------------------------------\n'
#                  '\n'
#                  '\n'
#                  'If your organization uses direct sign-on, you can change '
#                  'your password by following these steps:\n'
#                  '\n'
#                  '\n'
#                  '1. In the Domo navigation header, select\xa0your profile '
#                  'picture to expand the user action menu.\n'
#                  '2. Select\xa0\xa0**Settings**.\n'
#                  ' The user **Settings** page opens\xa0with the\xa0'
#                  '**General**tab selected by default.\n'
#                  '3. Under **Security**, select\xa0**Change your password**.\n'
#                  ' The **Change Password**\xa0fields display.\n'
#                  '4. Enter your current password in the\xa0**Current '
#                  'Password** field.\n'
#                  '5. Enter your new password in the\xa0**New Password**box. '
#                  'Your password\xa0may\xa0need to meet certain criteria, '
#                  "depending on your organization's settings. See Setting "
#                  'Password Requirements\xa0for more information.\n'
#                  '6. Reenter your new password in the\xa0**Retype New '
#                  'Password**\xa0field.\n'
#                  '7. Select **Save**\xa0to keep your new password or '
#                  '**Cancel**\xa0to return to the settings without changing '
#                  'your password.\n'
#                  '\n'
#                  '\n'
#                  'Change a Forgotten or Expired Password\n'
#                  '--------------------------------------\n'
#                  '\n'
#                  '\n'
#                  'If you forget your password to sign in to Domo, or if it '
#                  'expires, you can change your password from the login page if '
#                  'you know the email address for your account.\n'
#                  '\n'
#                  '\n'
#                  'For information about changing your password in your '
#                  'profile, see\xa0Specifying Your Personal Profile '
#                  'Information.\n'
#                  '\n'
#                  '\n'
#                  'Follow these steps to change your password from the login '
#                  'page:\n'
#                  '\n'
#                  '\n'
#                  "1. In an internet\xa0browser, enter your organization's domo "
#                  'URL in this format:\xa0https://*mycompany.*domo.com.\n'
#                  ' The login page displays.\n'
#                  '2. Select\xa0**Forgot password?**\n'
#                  ' A dialog displays.\n'
#                  '3. Enter your email address, then select\xa0**Request Reset '
#                  'Link**.\n'
#                  ' An email is sent to the email address.\n'
#                  '4. Log in to your email account and find the email '
#                  'message.\xa0The email message has the subject line '
#                  "**Forgotten Password**.\xa0If the email doesn't arrive, "
#                  'contact your Domo admin.\n'
#                  '5. Open the email message, then select **Reset Your '
#                  'Password**.\n'
#                  ' A dialog appears where you can change your password.\n'
#                  '6. Enter a new password in the first field.\n'
#                  '7. Reenter the same password in the second field.\n'
#                  '8. Select **Reset Your Password**. Your password may need to '
#                  'meet certain requirements. See Setting Password Requirements '
#                  'to learn more.\n'
#                  '\n'
#                  '\n'
#                  '**Note:**\xa0If for any reason you have issues while '
#                  'resetting your password, reach out to an Admin-level user or '
#                  'a user with a custom role for which the Edit Users grant has '
#                  'been enabled. These users have the ability to change a '
#                  'password for a particular user in the Admin Settings in '
#                  'Domo.\n'
#                  '\n'
#                  'hange Your Password Before It Expires\n'
#                  '--------------------------------------\n'
#                  '\n'
#                  '\n'
#                  'When password expiration is enabled, your password is set to '
#                  'expire after a specified amount of time. You can change your '
#                  'password in Domo before it expires.\n'
#                  '\n'
#                  '\n'
#                  'A few days before your password expires, a prompt displays '
#                  'after you sign in.\n'
#                  '\n'
#                  '\n'
#                  'Follow these steps to change your password before it '
#                  'expires:\n'
#                  '\n'
#                  '\n'
#                  '1. When prompted, select\xa0**Change your password**.\n'
#                  '2. Enter your current password that is expiring, then enter '
#                  'and confirm a new password.\xa0Your password may need to '
#                  'meet certain requirements. See Setting Password Requirements '
#                  'to learn more.\n'
#                  '3. Select\xa0**Save** to save your new password.\n'
#                  '\n'
#                  '\n'
#                  'Troubleshooting\n'
#                  '---------------\n'
#                  '\n'
#                  '\n'
#                  "If you try to reset your password and don't receive a "
#                  'password reset email, try the following:\n'
#                  '\n'
#                  '\n'
#                  '* Look in your email junk folder.\n'
#                  "* Verify your organization's authentication method—if your "
#                  'company uses SSO for authentication, no email is\xa0sent. '
#                  'Talk to your internal IT team to reset your password.\n'
#                  '* Check your Domo instance URL.\n'
#                  '\n'
#                  '\n'
#                  '**Important:**\xa0Your Domo instance URL should look like '
#                  'customername.domo.com. It is important to note that '
#                  'regardless of what you type in the customer name portion of '
#                  'the URL, a login page displays, however, your credentials do '
#                  "not work. Just because you see a login screen doesn't\xa0"
#                  'mean your URL is entered correctly.\n'
#                  '\n'
#                  '\n'
#                  'If you still have issues resetting your password, reach out '
#                  'to either an Admin-level user or a user with a custom role '
#                  'with the Edit Users grant enabled within your organization. '
#                  'These users have\xa0the ability to change a password for a '
#                  'particular user in the Admin Settings within Domo.\n'
#                  '\n'
#                  '\n'
#                  '**Important:**\xa0If another person changes your password, '
#                  'we strongly recommend that you follow the steps to change '
#                  'your password in user settings  after you regain access\xa0'
#                  'to ensure that your password remains secure.',
#  'type': 'Document'}

# %%
from langchain_community.chat_models.ollama import ChatOllama as Ollama

rag_client = Ollama(
    model="mistral:instruct",
    verbose=True,
    temperature = 0
)

# %%
# %pip install langchain_experimental --upgrade

# %%
example_q = """What Brian's height?

Source: 1
Information: Suzy is 6'2"

Source: 2
Information: Jeremiah is blonde

Source: 3
Information: Brian is 3 inches shorted than Suzy"""

# %%
from typing import List, Optional
from langchain_experimental.llms.ollama_functions import OllamaFunctions

from langchain_core.pydantic_v1 import BaseModel, Field

class cited_answer(BaseModel):
    """Answer the user question based only on the given sources, and cite the sources used."""

    answer: str = Field(
        ...,
        description="The answer to the user question, which is based only on the given sources.",
    )
    citations: List[int] = Field(
        ...,
        description="The integer IDs of the SPECIFIC sources which justify the answer.",
    )


model = OllamaFunctions(model="mistral:instruct", verbose = True)

model = rag_client.bind(functions = [cited_answer])

model.invoke(example_q)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 23
#      19 model = OllamaFunctions(model="mistral:instruct", verbose = True)
#      21 model = rag_client.bind(functions = [cited_answer])
# ---> 23 model.invoke(example_q)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:4517, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4511 def invoke(
#    4512     self,
#    4513     input: Input,
#    4514     config: Optional[RunnableConfig] = None,
#    4515     **kwargs: Optional[Any],
#    4516 ) -> Output:
# -> 4517     return self.bound.invoke(
#    4518         input,
#    4519         self._merge_configs(config),
#    4520         **{**self.kwargs, **kwargs},
#    4521     )
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:158, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     147 def invoke(
#     148     self,
#     149     input: LanguageModelInput,
#    (...)
#     153     **kwargs: Any,
#     154 ) -> BaseMessage:
#     155     config = ensure_config(config)
#     156     return cast(
#     157         ChatGeneration,
# --> 158         self.generate_prompt(
#     159             [self._convert_input(input)],
#     160             stop=stop,
#     161             callbacks=config.get("callbacks"),
#     162             tags=config.get("tags"),
#     163             metadata=config.get("metadata"),
#     164             run_name=config.get("run_name"),
#     165             run_id=config.pop("run_id", None),
#     166             **kwargs,
#     167         ).generations[0][0],
#     168     ).message
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:560, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     552 def generate_prompt(
#     553     self,
#     554     prompts: List[PromptValue],
#    (...)
#     557     **kwargs: Any,
#     558 ) -> LLMResult:
#     559     prompt_messages = [p.to_messages() for p in prompts]
# --> 560     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:421, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     419         if run_managers:
#     420             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 421         raise e
#     422 flattened_outputs = [
#     423     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     424     for res in results
#     425 ]
#     426 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:411, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     408 for i, m in enumerate(messages):
#     409     try:
#     410         results.append(
# --> 411             self._generate_with_cache(
#     412                 m,
#     413                 stop=stop,
#     414                 run_manager=run_managers[i] if run_managers else None,
#     415                 **kwargs,
#     416             )
#     417         )
#     418     except BaseException as e:
#     419         if run_managers:
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:632, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     630 else:
#     631     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 632         result = self._generate(
#     633             messages, stop=stop, run_manager=run_manager, **kwargs
#     634         )
#     635     else:
#     636         result = self._generate(messages, stop=stop, **kwargs)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_community/chat_models/ollama.py:259, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     235 def _generate(
#     236     self,
#     237     messages: List[BaseMessage],
#    (...)
#     240     **kwargs: Any,
#     241 ) -> ChatResult:
#     242     """Call out to Ollama's generate endpoint.
#     243
#     244     Args:
#    (...)
#     256             ])
#     257     """
# --> 259     final_chunk = self._chat_stream_with_aggregation(
#     260         messages,
#     261         stop=stop,
#     262         run_manager=run_manager,
#     263         verbose=self.verbose,
#     264         **kwargs,
#     265     )
#     266     chat_generation = ChatGeneration(
#     267         message=AIMessage(content=final_chunk.text),
#     268         generation_info=final_chunk.generation_info,
#     269     )
#     270     return ChatResult(generations=[chat_generation])
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_community/chat_models/ollama.py:190, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     181 def _chat_stream_with_aggregation(
#     182     self,
#     183     messages: List[BaseMessage],
#    (...)
#     187     **kwargs: Any,
#     188 ) -> ChatGenerationChunk:
#     189     final_chunk: Optional[ChatGenerationChunk] = None
# --> 190     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     191         if stream_resp:
#     192             chunk = _chat_stream_response_to_chat_generation_chunk(stream_resp)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_community/chat_models/ollama.py:162, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     152 def _create_chat_stream(
#     153     self,
#     154     messages: List[BaseMessage],
#     155     stop: Optional[List[str]] = None,
#     156     **kwargs: Any,
#     157 ) -> Iterator[str]:
#     158     payload = {
#     159         "model": self.model,
#     160         "messages": self._convert_messages_to_ollama_messages(messages),
#     161     }
# --> 162     yield from self._create_stream(
#     163         payload=payload, stop=stop, api_url=f"{self.base_url}/api/chat", **kwargs
#     164     )
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/langchain_community/llms/ollama.py:231, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     224 else:
#     225     request_payload = {
#     226         "prompt": payload.get("prompt"),
#     227         "images": payload.get("images", []),
#     228         **params,
#     229     }
# --> 231 response = requests.post(
#     232     url=api_url,
#     233     headers={
#     234         "Content-Type": "application/json",
#     235         **(self.headers if isinstance(self.headers, dict) else {}),
#     236     },
#     237     json=request_payload,
#     238     stream=True,
#     239     timeout=self.timeout,
#     240 )
#     241 response.encoding = "utf-8"
#     242 if response.status_code != 200:
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/models.py:371, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
# --> 371 self.prepare_body(data, files, json)
#     372 self.prepare_auth(auth, url)
#     374 # Note that prepare_auth must be last to enable authentication schemes
#     375 # such as OAuth to work on a fully prepared request.
#     376
#     377 # This MUST go after prepare_auth. Authenticators could add a hook
#
# File /home/GitHub/llama/.venv/lib/python3.10/site-packages/requests/models.py:511, in PreparedRequest.prepare_body(self, data, files, json)
#     508 content_type = "application/json"
#     510 try:
# --> 511     body = complexjson.dumps(json, allow_nan=False)
#     512 except ValueError as ve:
#     513     raise InvalidJSONError(ve, request=self)
#
# File /usr/lib/python3.10/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File /usr/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File /usr/lib/python3.10/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File /usr/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type ModelMetaclass is not JSON serializable

# %%
from langchain.output_parsers.openai_tools import JsonOutputKeyToolsParser

output_parser = JsonOutputKeyToolsParser(key_name="cited_answer", first_tool_only=True)



rag_client_func.invoke(example_q)

# %%
from operator import itemgetter
from typing import List


from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)

from urban_waffle import client as uwc


def format_docs(docs: List[Document]) -> str:
    """Convert Documents to a single string.:"""
    formatted = [
        f"Article Title: {doc.metadata['title']}\nArticle Snippet: {doc.page_content}"
        for doc in docs
    ]
    return "\n\n" + "\n\n".join(formatted)


format_chain = (
    itemgetter("docs") | RunnableLambda(format_docs)
)

# subchain for generating an answer once we've done retrieval
answer_chain = uwc.rag_prompt | rag_client_func | StrOutputParser()
# complete chain that calls wiki -> formats docs to string -> runs answer subchain -> returns just the answer and retrieved docs.

citation_chain = (
    RunnableParallel(question=RunnablePassthrough(), docs=retriever)
    .assign(context=format_chain)
    .assign(answer=answer_chain)
    .pick(["answer", "docs"])
)

# %%
citation_chain.invoke("can i reset my password if my company uses SSO?")

# %%
from urban_waffle import client as uwc

rag_chain = uwc.generate_rag_chain(retriever = retriever, rag_prompt = uwc.rag_prompt)

# %%
rag_chain.invoke("can i reset my password if my company uses SSO?")
